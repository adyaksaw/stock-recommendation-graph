# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
from tqdm import tqdm
from datetime import datetime
import os
import pickle
import seaborn

# %%
# %matplotlib inline
seaborn.set(rc={'figure.figsize':(15,8)})
seaborn.set(font_scale=1.2)

# %%
TIME_START = "20170101"
TIME_END = "20201231"

# %%
def convert_timestamp(string_time):
    temp_time = string_time.split()
    if temp_time[1] == 'mei':
        temp_time[1] = 'may'
    elif temp_time[1] == 'ags':
        temp_time[1] = 'aug'
    elif temp_time[1] == 'okt':
        temp_time[1] = 'oct'
    elif temp_time[1] == 'des':
        temp_time[1] = 'dec'
    fixed_string_time = " ".join(temp_time)
    datetime_obj = datetime.strptime(
        fixed_string_time, "%d %b %Y"
    )
    return datetime_obj.strftime('%Y%m%d')

stock_time_data = dict()
with open('../data/listing_date.csv', 'r') as file:
    reader = csv.reader(file, delimiter='|')
    for row in reader:
        row[2] = convert_timestamp(row[2])
        stock_time_data[row[0]] = row[2]

# %%
dump_file = open("../data/stock_price.obj", "rb")
price_list = pickle.load(dump_file)
price_list = {idx: gp.xs(idx, level=0, axis=1).dropna()
              for idx, gp in price_list.groupby(level=0, axis=1)}

# %%
def get_output(foldername):
    invalid = []

    df_overall = [None for i in range(5)]
    for filename in tqdm(os.listdir(f'../{foldername}/')):
        if filename.endswith('.csv'):
            df = pd.read_csv(os.path.join(f'../{foldername}/', filename), index_col=0)
            if(df.loc[1, 'max'] == 0 or df.loc[1].isnull().values.any()):
                invalid.append(filename.split('.')[0])
                continue
            for index, row in df.iterrows():
                if(df.loc[index, 'max'] != 0 and not df.loc[index].isnull().values.any()):
                    if type(df_overall[index]) == type(None):
                        df_overall[index] = df.loc[index]
                    else:
                        df_overall[index] = pd.concat([df_overall[index], df.loc[index]])

    for idx, df in enumerate(df_overall):
        if type(df) != type(None):
            max_df = df[['max']].reset_index(drop=True)
            min_df = df[['min']].reset_index(drop=True)
            avg_df = df[['avg']].reset_index(drop=True)
            median_df = df[['median']].reset_index(drop=True)
            count_df = df[['count']].reset_index(drop=True)
            df_overall[idx] = pd.concat([
                max_df,
                min_df,
                avg_df,
                median_df,
                count_df
            ], ignore_index=True, axis=1).rename(columns={0: 'max', 1: 'min', 2: 'avg', 3: 'median', 4: 'count'})
    
    return df_overall, invalid

def get_differences(df):
    median_data = [df[i][['median']] for i in range(4)]
    temp = [[], []]
    for i in range(len(median_data[0])):
        for j in range(2):
            temp[j].append(median_data[j+1].loc[i, 'median'] - median_data[j].loc[i, 'median'])
    return median_data, temp

# %%
def check_invalid(invalid):
    if(len(invalid) == 0):
        print("No invalid data")
    else:
        print(sorted(
        [(i, stock_time_data[i], len(price_list[f'{i}.JK'][TIME_START:TIME_END].Close)) for i in invalid],
        key=lambda k: k[1]
        ))

# %% [markdown]
# # Graph-Subset

# %%
foldername = 'output/output_subset_val'
df_output_subset_val, invalid = get_output(foldername)
check_invalid(invalid)
for i in range(4):
    plt.scatter(x = df_output_subset_val[i][['median']],
                y = df_output_subset_val[i][['count']],
                label=f"Jarak {i*2+2}"
               )
    plt.legend()
    plt.xlabel('Median')
    plt.ylabel('Jumlah Sampel')
    plt.suptitle('Persebaran Hasil Berdasarkan Jarak pada Eksperimen Graph-Subset')
    plt.savefig('../img/subset_val-scatter.png', bbox_inches='tight')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 703/703 [00:06<00:00, 114.19it/s]
# No invalid data

# %% [markdown]
# # Naive-All

# %%
df_output_all_naive = pd.read_csv('../output/output_all_naive/overall.csv', index_col=0)
seaborn.displot(
    data=df_output_all_naive[['median']]
).set(
    title='Frekuensi Nilai Median pada Eksperimen Naive-All',
    ylabel="Jumlah Sampel"
).savefig('../img/all_naive-dist.png', bbox_inches='tight')

# %%
df_output_all_naive[['median']].median()
# Out:
# median    0.42408
# dtype: float64

# %%
all_naive_lineplot = seaborn.lineplot(
    data = df_output_all_naive[['median']].reset_index().rename(
        columns={"index": 'count'}
    ),
    x = 'count',
    y = 'median'
).set(
    title='Diagram Garis Eksperimen Naive-All',
    xlabel='Jumlah Sampel',
    ylabel='Median'
)

plt.savefig('../img/all_naive-line.png', bbox_inches='tight')

# %% [markdown]
# # Naive-Subset

# %%
df_output_subset_naive = pd.read_csv('../output/output_subset_naive/overall.csv', index_col=0)
seaborn.lineplot(
    data=df_output_subset_naive[['median']]
    .reset_index()
    .rename(
        columns={"index": 'count'}
    ),
    x = 'median',
    y = 'count'
).set(
    xlabel='Median',
    ylabel="Jumlah Sampel",
    title='Diagram Garis Eksperimen Naive-Subset'
)

plt.savefig('../img/subset_naive-line.png', bbox_inches='tight')

# %%
seaborn.lineplot(data=df_output_subset_naive[['median']].reset_index()
                 .rename(columns={"index": 'count'}),
                 x = 'median',
                 y = 'count'
                )
merged_df = pd.concat([df_output_subset_val[0], df_output_subset_val[1], df_output_subset_val[2], df_output_subset_val[3]])
seaborn.scatterplot(
    data = merged_df,
    x = 'median',
    y = 'count',
    alpha = 0.3
).set(
    xlabel='Median',
    ylabel='Jumlah Sampel',
    title='Gabungan Diagram Garis Eksperimen Naive-Subset dan Diagram Persebaran Eksperimen Graph-Subset'
)

plt.savefig('../img/subset_naive-line-merged.png', bbox_inches='tight')

# %%
seaborn.lineplot(data=df_output_subset_naive[['median']].reset_index()
                 .rename(columns={"index": 'count'}),
                 x = 'median',
                 y = 'count',
                )
merged_df = pd.concat([df_output_subset_val[0], df_output_subset_val[1], df_output_subset_val[2], df_output_subset_val[3]])
merged_df = merged_df.groupby(by=['count']).median()
seaborn.lineplot(
    data = merged_df,
    x = 'median',
    y = 'count',
    alpha=0.5
).set(
    xlabel='Median',
    ylabel='Jumlah Sampel',
    title='Gabungan Diagram Garis Eksperimen Naive-Subset dan Diagram Garis Eksperimen Graph-Subset'
)
# Out:
#             max       min       avg    median
# count
# 1.0    0.416631  0.416631  0.416631  0.416631
# 2.0    0.625467  0.282846  0.476987  0.476987
# 3.0    0.538929  0.124413  0.347456  0.395731
# 4.0    0.522147  0.113458  0.350865  0.383926
# 5.0    0.682486  0.104993  0.362259  0.411501
# ...         ...       ...       ...       ...
# 365.0  0.012139  0.001612  0.006331  0.005196
# 378.0  0.007591  0.003347  0.005487  0.005134
# 386.0  0.007175  0.000102  0.004382  0.005563
# 412.0  0.109022  0.017256  0.061959  0.068583
# 434.0  0.069312  0.045349  0.060036  0.066032
#
# [288 rows x 4 columns]

# %%
seaborn.lineplot(data=df_output_subset_naive[['median']].reset_index()
                 .rename(columns={"index": 'count'}),
                 x = 'median',
                 y = 'count',
                )

temp_df = merged_df.reset_index()
seaborn.lineplot(
    data=temp_df[temp_df['count'] <= 100],
    x = 'median',
    y = 'count'
).set(
    xlabel='Median',
    ylabel='Jumlah Sampel',
    title='Gabungan Diagram Garis Eksperimen Naive-Subset dan Diagram Garis Eksperimen Graph-Subset'
)
plt.savefig('../img/subset_naive-median-line.png', bbox_inches='tight')
# Out:
# [Text(0.5, 0, 'Median'),
#  Text(0, 0.5, 'Jumlah Sampel'),
#  Text(0.5, 1.0, 'Gabungan Diagram Garis Eksperimen Naive-Subset dan Diagram Garis Eksperimen Graph-Subset')]

# %% [markdown]
# # Graph-All

# %%
foldername = 'output/output_all_val'
df_output_all_val, invalid = get_output(foldername)
check_invalid(invalid)
for i in range(4):
    print(len(df_output_all_val[i]))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 703/703 [00:06<00:00, 109.66it/s]
# No invalid data
# 703
# 703
# 703
# 131

# %%
for i in range(4):
    plt.scatter(
        x = df_output_all_val[i][['median']],
        y = df_output_all_val[i][['count']],
        label=f"Jarak {i*2+2}"
    )
    plt.legend()
    plt.xlabel('Median')
    plt.ylabel('Jumlah Sampel')
    
plt.suptitle('Persebaran Hasil pada Eksperimen Graph-All')
plt.savefig('../img/all_val-scatter.png', bbox_inches='tight')

# %%
median_data, differences_data = get_differences(df_output_all_val)
print(median_data[0].median(), median_data[1].median(), median_data[2].median(), median_data[3].median())

seaborn.boxplot(
    data=median_data
).set(
    xlabel='Jarak',
    ylabel='Median',
    title='Rentang Nilai Median Berdasarkan Jarak pada Eksperimen Graph-All',
)
plt.xticks([0, 1, 2, 3], [2, 4, 6, 8])
plt.savefig('../img/all_val_median-box.png', bbox_inches='tight')
# Out:
# median    0.449059
# dtype: float64 median    0.442779
# dtype: float64 median    0.43503
# dtype: float64 median    0.420595
# dtype: float64

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
fig.suptitle('Frekuensi Setiap Median Berdasarkan Jarak pada Eksperimen Graph-All')
for i in range(4):
    seaborn.histplot(ax = axes[i//2, i%2], data=median_data[i])
    axes[i//2, i%2].set_title(f"Jarak {i*2 + 2}")
    axes[i//2, i%2].set(xlabel="Median", ylabel="Jumlah")
plt.savefig('../img/all_val_median-distribution.png', bbox_inches='tight')

# %%
seaborn.boxplot(
    data=differences_data
).set(
    ylabel='Selisih Median',
    title='Persebaran Nilai Peningkatan Median Untuk Setiap Instans Data'
)
plt.xticks([0, 1], ['Jarak 2 Ke Jarak 4', 'Jarak 4 Ke Jarak 6'])
plt.savefig('../img/all_val_differences-box.png', bbox_inches='tight')

# %%
print(np.median(differences_data[0]))
print(np.median(differences_data[1]))
# Out:
# 0.001123646858163796
# -0.007807949491593247

# %%
seaborn.kdeplot(data=median_data[0])
seaborn.kdeplot(data=median_data[1])
seaborn.kdeplot(data=median_data[2])
plt.ylabel('Densitas')
plt.xlabel('Median')
plt.suptitle('Diagram KDE Median pada Eksperimen Graph-All')
plt.savefig('../img/all_val_median-displot.png', bbox_inches='tight')

# %% [markdown]
# # Graph-Random

# %%
foldername = 'output/output_random_val'
df_output_random_val, invalid = get_output(foldername)
check_invalid(invalid)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 702/702 [00:06<00:00, 108.40it/s]
# No invalid data

# %%
median_data, differences_data = get_differences(df_output_random_val)
print(median_data[0].median(), median_data[1].median(), median_data[2].median())

seaborn.boxplot(
    data=median_data
).set(
    xlabel='Jarak',
    ylabel='Median',
    xticklabels=[2, 4, 6, 8]
)
plt.savefig('../img/random_val_median-box.png', bbox_inches='tight')
# Out:
# median    0.433658
# dtype: float64 median    0.421414
# dtype: float64 median    0.413168
# dtype: float64

# %%
seaborn.boxplot(data=differences_data)
plt.xticks([0, 1], ['Jarak 4 Dengan Jarak 2', 'Jarak 6 Dengan Jarak 4'])
plt.ylabel('Selisih Median')
plt.savefig('../img/random_val_differences-box.png')

# %%
seaborn.kdeplot(data=median_data[0])
seaborn.kdeplot(data=median_data[1])
seaborn.kdeplot(data=median_data[2])
plt.ylabel('Densitas')
plt.xlabel('Median')

plt.suptitle('Diagram KDE Median pada Eksperimen Graph-Random')
plt.savefig('../img/random_val_median-displot.png')
